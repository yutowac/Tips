# %% [markdown]
# <a href="https://www.kaggle.com/code/yutodennou/tips-make-barcode?scriptVersionId=185662724" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# <a id="1"></a>
# # <div style="box-shadow: rgba(0, 0, 0, 0.16) 0px 1px 4px inset, rgb(51, 51, 51) 0px 0px 0px 3px inset; padding:20px; font-size:32px; font-family: consolas; text-align:center; display:fill; border-radius:15px;  color:rgb(34, 34, 34); background-color:rgb(255,255,255); "> <b> 1. Welcome to my tips page🎉 </b></div>
#
# <div style="
#     box-shadow: rgba(0, 0, 0, 0.3) 0px 3px 8px;
#     border-radius: 5px;
#     margin: 10px;
#     background-color: #E4C59E;
#     padding: 15px;
# ">
#     <p style="font-weight:bold; font-size: 16px; color: #333;">
#         This is really easy way!! You can meke Barcode to run a few lines
#     </p>
# </div>

# %% [markdown]
# <a id="2"></a>
# # <div style="box-shadow: rgba(0, 0, 0, 0.16) 0px 1px 4px inset, rgb(51, 51, 51) 0px 0px 0px 3px inset; padding:20px; font-size:32px; font-family: consolas; text-align:center; display:fill; border-radius:15px;  color:rgb(34, 34, 34); background-color:rgb(255,255,255); "> <b> 2. About Barcode⚙️</b></div>

# %% [markdown]
# **Bar codes contain POS (Point Of Sales) information such as country, industry, product name, and price, which are necessary for distribution and product management, and can be read by a handy terminal or bar code reader.
# In general, the term "barcode" refers to one-dimensional codes, but ISO/IEC standards refer to barcodes as two-dimensional codes as well.
# Please refer [this notebook]() if you make QR code, one of two-dimentional codes.**

# %% [markdown]
# **It is said that there are more than 100 types of barcode formats in the world.
# [python-barcode](https://python-barcode.readthedocs.io/en/stable/contents.html#) is a library for generating barcodes in various formats.**
#
# **python-barcode supports below formats:**

# %% [markdown]
# <div style="background-color:#f0fae9; padding:6px 20px; border-radius:15px; font-size:20px">
#     <ul style="margin-left:10px ; font-size:16px;">
#       <li>Code39</li>
#       <li>Code128</li>
#       <li>PZN7</li>
#       <li>EAN-13</li>
#       <li>EAN-8</li>
#       <li>JAN</li>
#       <li>ISBN-13</li>
#       <li>ISBN-10</li>
#       <li>ISSN</li>
#       <li>UPC-A</li>
#       <li>EAN14</li>
#       <li>GS1-128</li>
#     </ul>
# </div>

# %% [markdown]
# <a id="3"></a>
# # <div style="box-shadow: rgba(0, 0, 0, 0.16) 0px 1px 4px inset, rgb(51, 51, 51) 0px 0px 0px 3px inset; padding:20px; font-size:32px; font-family: consolas; text-align:center; display:fill; border-radius:15px;  color:rgb(34, 34, 34); background-color:rgb(255,255,255); "> <b> 3. Import library🗃️</b></div>

# %%
# https://pypi.org/project/python-barcode/
# !pip install python-barcode
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 kB 4.4 MB/s eta 0:00:00
# ...

# %%
from barcode import EAN13
from barcode import Code39
from barcode.writer import SVGWriter

# %% [markdown]
# <a id="4"></a>
# # <div style="box-shadow: rgba(0, 0, 0, 0.16) 0px 1px 4px inset, rgb(51, 51, 51) 0px 0px 0px 0px inset; padding:20px; font-size:32px; font-family: consolas; text-align:center; display:fill; border-radius:15px;  border:#E57C23 solid; color:rgb(34, 34, 34); background-color: #FFFAF0; "> <b> 4. Make Barcodes🌟</b></div>

# %% [markdown]
# <a id="4-1"></a>
# ## <div style="padding:20px; font-size:32px; font-family: consolas; text-align:center; display:fill; border-radius:15px;  color:rgb(51, 151, 51); background-color:rgb(255,255,255); "> <b> Barcode with Number🛠️</b></div>

# %%
with open("file_number.svg", "wb") as f:
    EAN13("111111111111", writer=SVGWriter()).write(f)

# %% [markdown]
# ![image.png](attachment:e9ae0c5e-618d-4859-bfbf-ae6d80e99a73.png)

# %% [markdown]
# <a id="4-1"></a>
# ## <div style="padding:20px; font-size:32px; font-family: consolas; text-align:center; display:fill; border-radius:15px;  color:rgb(51, 151, 51); background-color:rgb(255,255,255); "> <b> Barcode with String🛠️</b></div>

# %%
with open("somefile_string.svg", "wb") as f:
    Code39("WelcomeKagglers", writer=SVGWriter()).write(f)

# %% [markdown]
# ![image.png](attachment:3af1b200-29ca-4dcc-8845-91606e4afe40.png)
