# %% [markdown]
# <a href="https://www.kaggle.com/code/yutodennou/tips-make-barcode?scriptVersionId=147673691" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # 🎉Welcome to my tips page

# %% [markdown]
# This is really easy way!!
#
# You can meke Bar code to run a few lines

# %% [markdown]
# ## 🗃️Import library

# %%
# https://pypi.org/project/python-barcode/
# !pip install python-barcode
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 213.0/213.0 kB 8.1 MB/s eta 0:00:00
# ...

# %%
from barcode import EAN13
from barcode import Code39
from barcode.writer import SVGWriter

# %% [markdown]
# ## 🛠️Barcode with Number

# %%
with open("file_number.svg", "wb") as f:
    EAN13("111111111111", writer=SVGWriter()).write(f)

# %% [markdown]
# ## 🛠️Barcode with String

# %%
with open("somefile_string.svg", "wb") as f:
    Code39("WelcomeKagglers", writer=SVGWriter()).write(f)
